# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
df = pd.read_csv("King_County_house_prices_dataset.csv")
df["price"] = df["price"].apply(lambda x: x*0.001)
df["bathrooms"] = df["bathrooms"].apply(lambda x: round(x))
df["sqft_lot"] = df["sqft_lot"].apply(lambda x: x*0.001)
df["sqft_living"] = df["sqft_living"].apply(lambda x: x*0.001)
df["sqft_above"] = df["sqft_above"].apply(lambda x: x*0.001)
df["sqft_living15"] = df["sqft_living15"].apply(lambda x: x*0.001)
df["sqft_lot15"] = df["sqft_lot15"].apply(lambda x: x*0.001)
df["price_per_sqft_lot"] = df.eval("price / sqft_lot")
df["price_per_sqft_living"] = df.eval("price / sqft_living")
df.head(5)
# Out:
#            id        date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  10/13/2014  221.9         3          1         1.18     5.650
# 1  6414100192   12/9/2014  538.0         3          2         2.57     7.242
# 2  5631500400   2/25/2015  180.0         2          1         0.77    10.000
# 3  2487200875   12/9/2014  604.0         4          3         1.96     5.000
# 4  1954400510   2/18/2015  510.0         3          2         1.68     8.080
#
#    floors  waterfront  view  ...  sqft_basement  yr_built  yr_renovated  \
# 0     1.0         NaN   0.0  ...            0.0      1955           0.0
# 1     2.0         0.0   0.0  ...          400.0      1951        1991.0
# 2     1.0         0.0   0.0  ...            0.0      1933           NaN
# 3     1.0         0.0   0.0  ...          910.0      1965           0.0
# 4     1.0         0.0   0.0  ...            0.0      1987           0.0
#
# ...

# %%
high_price_p_sqft = df.groupby("zipcode").price_per_sqft_living.mean().sort_values(ascending=False).head(15).reset_index()
high_price_p_sqft
# Out:
#     zipcode  price_per_sqft_living
# 0     98039             568.241828
# 1     98004             475.609615
# 2     98112             438.877517
# 3     98109             433.559416
# 4     98119             432.352127
# 5     98102             423.868193
# 6     98105             405.283209
# 7     98040             387.479406
# 8     98107             382.968248
# 9     98199             376.659850
# 10    98103             369.882756
# 11    98122             367.576528
# 12    98117             363.546251
# 13    98115             354.157213
# 14    98116             348.569255

# %%
sns.lmplot('price_per_sqft_living', 'price',data=df);
# Out:
# /opt/anaconda3/envs/kingcounty/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('price_per_sqft_lot', 'price',data=df);
# Out:
# /opt/anaconda3/envs/kingcounty/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.subplots(figsize=(17,14))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="Black",fmt="1.1f")
plt.title("Data Correlation",fontsize=50)
plt.show()

# %%
sns.set()
plt.plot(df.yr_built, df.price)
plt.legend('price', ncol=1, loc='upper left');

# %%
df3 = pd.read_csv("King_County_house_prices_dataset.csv")


'''df3["price"] = df["price"].apply(lambda x: x*0.001)
df3["bathrooms"] = df["bathrooms"].apply(lambda x: round(x))
df3["sqft_lot"] = df["sqft_lot"].apply(lambda x: x*0.001)
df3["sqft_living"] = df["sqft_living"].apply(lambda x: x*0.001)
df3["sqft_above"] = df["sqft_above"].apply(lambda x: x*0.001)
df["sqft_living15"] = df["sqft_living15"].apply(lambda x: x*0.001)
df["sqft_lot15"]'''

df3.head(5)
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...
